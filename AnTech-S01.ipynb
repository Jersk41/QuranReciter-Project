# %%
#merubah audio jadi High Level Feature
import matplotlib.pyplot as plt
import librosa.display
import librosa
import numpy as np
def Ubah_high_level_feature(sound_path):
    y, sr =librosa.load(sound_path)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
    plt.figure(figsize=(10,4))
    S_dB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr,fmax=8000)
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel-frequency spectogram')
    plt.tight_layout()
    plt.show()

path = "../QuranReciter-Project/SourceSound/S01.ogg"
Ubah_high_level_feature(path)

# %%
import IPython.display as ipd

y, sr = librosa.load(path, sr=11025)
ipd.Audio(y,rate=11025)

def plot_time_series(data):
    fig = plt.figure(figsize=(14, 8))
    plt.title('Raw wave ')
    plt.ylabel('Amplitude')
    plt.plot(np.linspace(0, 1, len(data)), data)
    plt.show()

plot_time_series(data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
